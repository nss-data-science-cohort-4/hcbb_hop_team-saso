# %% [markdown]
# To import libraries

# %%
import pandas as pd
import sqlite3
from tqdm.notebook import tqdm
pd.set_option('display.max_columns', 999)

# %%
hops = pd.read_csv('data/DocGraph_Hop_Teaming_2017_Non_Commercial/DocGraph_Hop_Teaming_2017.csv', 
                          nrows = 10000)

# %%
hops.to_csv('hops_for_Sav.csv')

# %%
hops.head()
# Out:
#    entity type 1  entity type 2  patient_count  transaction_count  \
# 0     1003863580     1000000004             19                 19
# 1     1043250400     1000000004             20                 20
# 2     1033239413     1000000004             20                 20
# 3     1033142146     1000000004            491                535
# 4     1013957562     1000000004             25                 26
#
#    average_day_wait  std_day_wait
# 0           108.895        84.598
# 1            87.000        77.173
# 2            58.800        76.982
# 3            10.232        36.558
# 4            78.692        59.305

# %% [markdown]
# Rename Columns Code for when we upload data to SQLite Database

# %%
hops = hops.rename({"from_npi":"entity type 1","to_npi":"entity type 2"}, axis='columns')

# %%
hops = pd.read_csv('data/DocGraph_Hop_Teaming_2017_Non_Commercial/DocGraph_Hop_Teaming_2017.csv', 
                          chunksize = 10000)

hops_df = pd.DataFrame([])

for hop in hops:
    hops_df = hops_df.append(hop)

# %%
endpoint = pd.read_csv('data/NPPES_Data_Dissemination_February_2021/endpoint_pfile_20050523-20210207.csv', 
                          nrows = 10000)

# %%
endpoint
# Out:
#              NPI Endpoint Type Endpoint Type Description  \
# 0     1699778894        DIRECT  Direct Messaging Address
# 1     1841293040       CONNECT               CONNECT URL
# 2     1306849591        DIRECT  Direct Messaging Address
# 3     1912900960       CONNECT               CONNECT URL
# 4     1629071675        DIRECT  Direct Messaging Address
# ...          ...           ...                       ...
# 9995  1558349787        DIRECT  Direct Messaging Address
# 9996  1912985151        DIRECT  Direct Messaging Address
# 9997  1114905353        DIRECT  Direct Messaging Address
# 9998  1922086164        DIRECT  Direct Messaging Address
# 9999  1659359800        OTHERS                 Other URL
#
#                                         Endpoint Affiliation  \
# 0                   aawomolo@direct.iuhealth.org           N
# 1      Jennifer.Giles_1@direct.cyfluentchart.com           N
# 2               svogel89246@direct.geisinger.edu           N
# ...

# %%
npidata = pd.read_csv('data/NPPES_Data_Dissemination_February_2021/npidata_pfile_20050523-20210207.csv', 
                          nrows = 10000)
# Out:
# C:\Users\alvin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (17,34,76,80,84,87,89,90,91,93,94,95,97,98,99,101,102,103,105,106,171,175,178,179,181,182,183,185,186,189,190,191,193,194,197,198,201,205,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
npidata
# Out:
#              NPI  Entity Type Code  Replacement NPI  \
# 0     1679576722               1.0              NaN
# 1     1588667638               1.0              NaN
# 2     1497758544               2.0              NaN
# 3     1306849450               1.0              NaN
# 4     1215930367               1.0              NaN
# ...          ...               ...              ...
# 9995  1700889045               1.0              NaN
# 9996  1619970951               1.0              NaN
# 9997  1528061868               2.0              NaN
# 9998  1437152774               1.0              NaN
# 9999  1346243680               2.0              NaN
#
#      Employer Identification Number (EIN)  \
# 0                                     NaN
# 1                                     NaN
# 2                               <UNAVAIL>
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# ...

# %%
npidata['Entity Type Code'].unique()
# Out:
# array([ 1.,  2., nan])

# %%
othername = pd.read_csv('data/NPPES_Data_Dissemination_February_2021/othername_pfile_20050523-20210207.csv', 
                          nrows = 10000)

# %%
othername
# Out:
#              NPI          Provider Other Organization Name  \
# 0     1023011053   Vine Discount Pharmacy & Medical Supply
# 1     1023011178  Napa Valley Hospice & Adult Day Services
# 2     1043213093                   HOME IV SPECIALISTS INC
# 3     1053314252                         Alliance HomeCare
# 4     1134122328                 Horizon Coral Springs LLC
# ...          ...                                       ...
# 9995  1497741748             MANKATO PROFESSIONAL PHARMACY
# 9996  1497741763        ST CATHERINE OF SIENA NURSING HOME
# 9997  1508852864           EMERSON REHAB. & NURSING CENTER
# 9998  1518953801   Blount Memorial Home Equipment Services
# 9999  1528054814                Nehalem Valley Care Center
#
#       Provider Other Organization Name Type Code
# 0                                              3
# 1                                              4
# 2                                              3
# 3                                              3
# ...

# %%
pl = pd.read_csv('data/NPPES_Data_Dissemination_February_2021/pl_pfile_20050523-20210207.csv', 
                          nrows = 10000)

# %%
pl
# Out:
#              NPI Provider Secondary Practice Location Address- Address Line 1  \
# 0     1124021324                          31 S Stanfield Rd Ste 104
# 1     1124021324                                   3333 W Tech Blvd
# 2     1063415271                          560 Riverside Dr Ste A206
# 3     1699778894                                     7420 Market St
# 4     1699778894                                 1520 Physicians Dr
# ...          ...                                                ...
# 9995  1508854407                                   10210 Couloak Dr
# 9996  1174511091                                  1605 E Evesham Rd
# 9997  1326036245                                  1605 E Evesham Rd
# 9998  1326036245                      900 Medical Center Dr Ste 201
# 9999  1326037250                                960 W University Dr
#
#      Provider Secondary Practice Location Address-  Address Line 2  \
# 0                                                   NaN
# ...

# %%
crosswalk = pd.read_excel('data/ZIP_CBSA Crosswalk.xlsx')

# %%
crosswalk
# Out:
#          ZIP   CBSA  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0        501  35620        0.0        1.0        0.0        1.0
# 1        601  38660        1.0        1.0        1.0        1.0
# 2        602  10380        1.0        1.0        1.0        1.0
# 3        603  10380        1.0        1.0        1.0        1.0
# 4        604  10380        1.0        1.0        1.0        1.0
# ...      ...    ...        ...        ...        ...        ...
# 47419  99925  99999        0.0        0.0        1.0        1.0
# 47420  99926  99999        0.0        0.0        1.0        1.0
# 47421  99927  99999        0.0        0.0        1.0        1.0
# 47422  99928  28540        0.0        0.0        1.0        1.0
# 47423  99929  99999        0.0        0.0        1.0        1.0
#
# [47424 rows x 6 columns]

# %%
taxonomy = pd.read_csv('data/nucc_taxonomy_210.csv')

# %%
taxonomy
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 860  343800000X              Transportation Services
# 861  344600000X              Transportation Services
# 862  347D00000X              Transportation Services
# 863  347E00000X              Transportation Services
# 864  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# ...
